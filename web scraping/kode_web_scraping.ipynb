# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium.webdriver.common.by import By
from selenium import webdriver

def driverSetup():
  options = webdriver.ChromeOptions()
  options.add_argument('--headless')
  options.add_argument('--no-sandbox')
  options.add_argument('--disable-dev-shm-usage')
  # open it, go to a website, and get results
  wd = webdriver.Chrome(options=options)
  return wd
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# ...

# %%
def writeToFile(idx, text):
  with open('/content/input/input'+idx+'.txt','w')as f:
    f.write(text)

# %%
def outputRes(idx):
  wd = driverSetup()
  wd.get("https://www.puzzle-minesweeper.com/mosaic-5x5-easy/")
  # print(wd.page_source)  # results
  elements = wd.find_elements(By.CLASS_NAME,'number')
  res = ''
  for x in elements:
    if(x.text == ""):
        res += '-1'
        res += '\n'
    else:
        res += x.text
        res += '\n'

    writeToFile(str(idx),res)

# %%
x = 0
for i in range(1000):
  outputRes(x)
  x=x+1

# %%
# !zip -r /content/input.zip /content/input
# Out:
#   adding: content/input/ (stored 0%)
#   adding: content/input/input450.txt (deflated 61%)
#   adding: content/input/input894.txt (deflated 59%)
#   adding: content/input/input425.txt (deflated 61%)
#   adding: content/input/input618.txt (deflated 63%)
#   adding: content/input/input734.txt (deflated 53%)
#   adding: content/input/input814.txt (deflated 64%)
#   adding: content/input/input179.txt (deflated 64%)
#   adding: content/input/input393.txt (deflated 59%)
#   adding: content/input/input670.txt (deflated 61%)
#   adding: content/input/input261.txt (deflated 58%)
#   adding: content/input/input172.txt (deflated 63%)
#   adding: content/input/input453.txt (deflated 57%)
#   adding: content/input/input283.txt (deflated 67%)
#   adding: content/input/input765.txt (deflated 59%)
#   adding: content/input/input866.txt (deflated 60%)
#   adding: content/input/input488.txt (deflated 57%)
#   adding: content/input/input925.txt (deflated 66%)
# ...

# %%
from google.colab import files
files.download('/content/input.zip')
# Out:
# rm: cannot remove '/content/input0.txt': No such file or directory
# rm: cannot remove '/content/input1.txt': No such file or directory
# rm: cannot remove '/content/input2.txt': No such file or directory
# rm: cannot remove '/content/input3.txt': No such file or directory
# rm: cannot remove '/content/input4.txt': No such file or directory
# rm: cannot remove '/content/input5.txt': No such file or directory
# rm: cannot remove '/content/input6.txt': No such file or directory
# rm: cannot remove '/content/input7.txt': No such file or directory
# rm: cannot remove '/content/input8.txt': No such file or directory
# rm: cannot remove '/content/input9.txt': No such file or directory
